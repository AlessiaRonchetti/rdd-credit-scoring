# %% [markdown]
# <a href="https://colab.research.google.com/github/AlessiaRonchetti/rdd-credit-scoring/blob/main/python-basics/google-colab-r.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
